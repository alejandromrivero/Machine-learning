# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from statsmodels.stats.tests.test_multi import NA

# %%
frame=pd.DataFrame(np.arange(100).reshape(25,4),
                   index=np.arange(25),
                   columns=['Colorado','Ohio','Florida','New Jersey'])
frame.index.names=['code']
frame
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Colorado</th>
#       <th>Ohio</th>
#       <th>Florida</th>
#       <th>New Jersey</th>
#     </tr>
#     <tr>
#       <th>code</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>1</td>
#       <td>2</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>4</td>
#       <td>5</td>
#       <td>6</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>8</td>
#       <td>9</td>
#       <td>10</td>
#       <td>11</td>
#     </tr>
#     <tr>
# ...

# %%
frame.iloc[12].mean()
# Out:
# 49.5

# %%
frame.iloc[12].var()
# Out:
# 1.6666666666666667

# %%
min_65=frame[frame<60]
min_65
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Colorado</th>
#       <th>Ohio</th>
#       <th>Florida</th>
#       <th>New Jersey</th>
#     </tr>
#     <tr>
#       <th>code</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0.0</td>
#       <td>1.0</td>
#       <td>2.0</td>
#       <td>3.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>4.0</td>
#       <td>5.0</td>
#       <td>6.0</td>
#       <td>7.0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>8.0</td>
#       <td>9.0</td>
#       <td>10.0</td>
#       <td>11.0</td>
# ...

# %%
min_65.dropna()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Colorado</th>
#       <th>Ohio</th>
#       <th>Florida</th>
#       <th>New Jersey</th>
#     </tr>
#     <tr>
#       <th>code</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0.0</td>
#       <td>1.0</td>
#       <td>2.0</td>
#       <td>3.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>4.0</td>
#       <td>5.0</td>
#       <td>6.0</td>
#       <td>7.0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>8.0</td>
#       <td>9.0</td>
#       <td>10.0</td>
#       <td>11.0</td>
# ...

# %%
indice_min65=np.random.rand(25)
min_65index=pd.DataFrame(np.round(np.random.rand(25),4), columns=['percent'])
min_65index.index.names=['code']

# %%
datos=pd.merge(min_65,min_65index, on='code')

# %%
datos
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Colorado</th>
#       <th>Ohio</th>
#       <th>Florida</th>
#       <th>New Jersey</th>
#       <th>percent</th>
#     </tr>
#     <tr>
#       <th>code</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0.0</td>
#       <td>1.0</td>
#       <td>2.0</td>
#       <td>3.0</td>
#       <td>0.3996</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>4.0</td>
#       <td>5.0</td>
#       <td>6.0</td>
#       <td>7.0</td>
#       <td>0.5908</td>
#     </tr>
#     <tr>
#       <th>2</th>
# ...

# %%
da=datos.fillna({'Colorado':datos['Colorado'].mean(), 'Ohio':datos['Ohio'].mean(),
                 'Florida':datos['Florida'].median(),
                 'New Jersey':datos['New Jersey'].mean()})

# %%
da
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Colorado</th>
#       <th>Ohio</th>
#       <th>Florida</th>
#       <th>New Jersey</th>
#       <th>percent</th>
#     </tr>
#     <tr>
#       <th>code</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0.0</td>
#       <td>1.0</td>
#       <td>2.0</td>
#       <td>3.0</td>
#       <td>0.3996</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>4.0</td>
#       <td>5.0</td>
#       <td>6.0</td>
#       <td>7.0</td>
#       <td>0.5908</td>
#     </tr>
#     <tr>
#       <th>2</th>
# ...

# %%
da.sort_values(by='percent', ascending=False)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Colorado</th>
#       <th>Ohio</th>
#       <th>Florida</th>
#       <th>New Jersey</th>
#       <th>percent</th>
#     </tr>
#     <tr>
#       <th>code</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>9</th>
#       <td>36.0</td>
#       <td>37.0</td>
#       <td>38.0</td>
#       <td>39.0</td>
#       <td>0.9931</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>24.0</td>
#       <td>25.0</td>
#       <td>26.0</td>
#       <td>27.0</td>
#       <td>0.9242</td>
#     </tr>
#     <tr>
# ...
