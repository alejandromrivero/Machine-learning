# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %% [markdown]
# ###Importing Data

# %%
raw_csv_data=pd.read_csv('F:/Time series com Python\Time Series Analysis in Python 2020/03 Introduction to Time Series in Python/013 IndexE8.csv')
df_comp=raw_csv_data.copy()

# %% [markdown]
# ###Examining data

# %%
df_comp.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>date</th>
#       <th>spx</th>
#       <th>dax</th>
#       <th>ftse</th>
#       <th>nikkei</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>07/01/1994</td>
#       <td>469.90</td>
#       <td>2224.95</td>
#       <td>3445.98</td>
#       <td>18124.01</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>10/01/1994</td>
#       <td>475.27</td>
#       <td>2225.00</td>
#       <td>3440.58</td>
#       <td>18443.44</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>11/01/1994</td>
#       <td>474.13</td>
#       <td>2228.10</td>
#       <td>3413.77</td>
# ...

# %%
df_comp
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>date</th>
#       <th>spx</th>
#       <th>dax</th>
#       <th>ftse</th>
#       <th>nikkei</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>07/01/1994</td>
#       <td>469.900000</td>
#       <td>2224.95</td>
#       <td>3445.980000</td>
#       <td>18124.01</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>10/01/1994</td>
#       <td>475.270000</td>
#       <td>2225.00</td>
#       <td>3440.580000</td>
#       <td>18443.44</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>11/01/1994</td>
#       <td>474.130000</td>
#       <td>2228.10</td>
# ...

# %%
df_comp.describe()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>spx</th>
#       <th>dax</th>
#       <th>ftse</th>
#       <th>nikkei</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>count</th>
#       <td>6269.000000</td>
#       <td>6269.000000</td>
#       <td>6269.000000</td>
#       <td>6269.000000</td>
#     </tr>
#     <tr>
#       <th>mean</th>
#       <td>1288.127542</td>
#       <td>6080.063363</td>
#       <td>5422.713545</td>
#       <td>14597.055700</td>
#     </tr>
#     <tr>
#       <th>std</th>
#       <td>487.586473</td>
#       <td>2754.361032</td>
#       <td>1145.572428</td>
#       <td>4043.122953</td>
#     </tr>
#     <tr>
# ...

# %%
df_comp.spx.isna().sum()
# Out:
# 0

# %%
df_comp['spx']
# Out:
# 0        469.900000
# 1        475.270000
# 2        474.130000
# 3        474.170000
# 4        472.470000
#            ...
# 6264    2839.130362
# 6265    2837.544008
# 6266    2839.253031
# 6267    2872.867839
# 6268    2853.528411
# Name: spx, Length: 6269, dtype: float64

# %% [markdown]
# ###Plotting the data

# %%
plt.figure(figsize=(20,5))
plt.plot(df_comp['spx'], color='g', label='spx')
plt.plot(df_comp['dax'], color='r', label='dax')
plt.plot(df_comp['ftse'], color='b', label='ftse')
plt.plot(df_comp['nikkei'], color='orange', label='nikkei')
plt.legend()
plt.title('SPX, DAX, FTSE & NIKKEI',color='blue', fontsize=14)
plt.savefig('F:/invento.png')
plt.show()

# %% [markdown]
# ###QQ Plot

# %%
import scipy.stats
import pylab

# %%
scipy.stats.probplot(df_comp['spx'], plot=pylab)
plt.savefig('F:/pylab.jpg')
pylab.show()

# %% [markdown]
# ###Transforming String inputs into DateTime Values

# %%
df_comp['date'].describe()
# Out:
# count           6269
# unique          6269
# top       09/02/2005
# freq               1
# Name: date, dtype: object

# %%
df_comp['date']=pd.to_datetime(df_comp['date'], dayfirst=True)

# %%
df_comp
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>date</th>
#       <th>spx</th>
#       <th>dax</th>
#       <th>ftse</th>
#       <th>nikkei</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1994-01-07</td>
#       <td>469.900000</td>
#       <td>2224.95</td>
#       <td>3445.980000</td>
#       <td>18124.01</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1994-01-10</td>
#       <td>475.270000</td>
#       <td>2225.00</td>
#       <td>3440.580000</td>
#       <td>18443.44</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>1994-01-11</td>
#       <td>474.130000</td>
#       <td>2228.10</td>
# ...

# %%
df_comp['date'].describe()
# Out:
# count                    6269
# unique                   6269
# top       1999-08-23 00:00:00
# freq                        1
# first     1994-01-07 00:00:00
# last      2018-01-29 00:00:00
# Name: date, dtype: object

# %% [markdown]
# ###Using Date as an Index

# %%
df_comp.set_index('date', inplace=True)

# %% [markdown]
# ###Setting the Frequency

# %%
df_comp.dtypes
# Out:
# spx       float64
# dax       float64
# ftse      float64
# nikkei    float64
# dtype: object

# %%
df_comp=df_comp.asfreq('b')
df_comp
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>spx</th>
#       <th>dax</th>
#       <th>ftse</th>
#       <th>nikkei</th>
#     </tr>
#     <tr>
#       <th>date</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1994-01-07</th>
#       <td>469.900000</td>
#       <td>2224.95</td>
#       <td>3445.980000</td>
#       <td>18124.01</td>
#     </tr>
#     <tr>
#       <th>1994-01-10</th>
#       <td>475.270000</td>
#       <td>2225.00</td>
#       <td>3440.580000</td>
#       <td>18443.44</td>
#     </tr>
#     <tr>
#       <th>1994-01-11</th>
#       <td>474.130000</td>
# ...

# %%
df_comp.describe(
	
)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>spx</th>
#       <th>dax</th>
#       <th>ftse</th>
#       <th>nikkei</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>count</th>
#       <td>6269.000000</td>
#       <td>6269.000000</td>
#       <td>6269.000000</td>
#       <td>6269.000000</td>
#     </tr>
#     <tr>
#       <th>mean</th>
#       <td>1288.127542</td>
#       <td>6080.063363</td>
#       <td>5422.713545</td>
#       <td>14597.055700</td>
#     </tr>
#     <tr>
#       <th>std</th>
#       <td>487.586473</td>
#       <td>2754.361032</td>
#       <td>1145.572428</td>
#       <td>4043.122953</td>
#     </tr>
#     <tr>
# ...

# %%
df_comp
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>spx</th>
#       <th>dax</th>
#       <th>ftse</th>
#       <th>nikkei</th>
#     </tr>
#     <tr>
#       <th>date</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1994-01-07</th>
#       <td>469.900000</td>
#       <td>2224.95</td>
#       <td>3445.980000</td>
#       <td>18124.01</td>
#     </tr>
#     <tr>
#       <th>1994-01-10</th>
#       <td>475.270000</td>
#       <td>2225.00</td>
#       <td>3440.580000</td>
#       <td>18443.44</td>
#     </tr>
#     <tr>
#       <th>1994-01-11</th>
#       <td>474.130000</td>
# ...

# %% [markdown]
# ###Filling Missing Values

# %%
df_comp.isna().sum()
# Out:
# spx       8
# dax       8
# ftse      8
# nikkei    8
# dtype: int64

# %%
df_comp['spx']=df_comp['spx'].fillna(method='ffill')
df_comp['dax']=df_comp['dax'].fillna(df_comp['dax'].mean())
df_comp['ftse']=df_comp['ftse'].fillna(method='bfill')
df_comp['nikkei']=df_comp['nikkei'].fillna(df_comp['nikkei'].mean())
df_comp.isna().sum()
# Out:
# spx       0
# dax       0
# ftse      0
# nikkei    0
# dtype: int64

# %%
dg=df_comp.drop(['dax','ftse','nikkei'], axis=1)
dg
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>spx</th>
#     </tr>
#     <tr>
#       <th>date</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1994-01-07</th>
#       <td>469.900000</td>
#     </tr>
#     <tr>
#       <th>1994-01-10</th>
#       <td>475.270000</td>
#     </tr>
#     <tr>
#       <th>1994-01-11</th>
#       <td>474.130000</td>
#     </tr>
#     <tr>
#       <th>1994-01-12</th>
#       <td>474.170000</td>
#     </tr>
#     <tr>
#       <th>1994-01-13</th>
#       <td>472.470000</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>2018-01-23</th>
# ...

# %%
dg['market value']=dg['spx']
dg
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>spx</th>
#       <th>market value</th>
#     </tr>
#     <tr>
#       <th>date</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1994-01-07</th>
#       <td>469.900000</td>
#       <td>469.900000</td>
#     </tr>
#     <tr>
#       <th>1994-01-10</th>
#       <td>475.270000</td>
#       <td>475.270000</td>
#     </tr>
#     <tr>
#       <th>1994-01-11</th>
#       <td>474.130000</td>
#       <td>474.130000</td>
#     </tr>
#     <tr>
#       <th>1994-01-12</th>
#       <td>474.170000</td>
#       <td>474.170000</td>
#     </tr>
#     <tr>
# ...

# %%
df_comp=dg.drop('spx', axis=1)
df_comp
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>market value</th>
#     </tr>
#     <tr>
#       <th>date</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1994-01-07</th>
#       <td>469.900000</td>
#     </tr>
#     <tr>
#       <th>1994-01-10</th>
#       <td>475.270000</td>
#     </tr>
#     <tr>
#       <th>1994-01-11</th>
#       <td>474.130000</td>
#     </tr>
#     <tr>
#       <th>1994-01-12</th>
#       <td>474.170000</td>
#     </tr>
#     <tr>
#       <th>1994-01-13</th>
#       <td>472.470000</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>2018-01-23</th>
# ...

# %% [markdown]
# ###Splitting Up the Data

# %%
size=int(len(df_comp)*0.8)

# %%
df=df_comp.iloc[:size]
df_test=df_comp.iloc[size:]

# %%
df.tail()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>market value</th>
#     </tr>
#     <tr>
#       <th>date</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2013-04-01</th>
#       <td>1562.173837</td>
#     </tr>
#     <tr>
#       <th>2013-04-02</th>
#       <td>1570.252238</td>
#     </tr>
#     <tr>
#       <th>2013-04-03</th>
#       <td>1553.686978</td>
#     </tr>
#     <tr>
#       <th>2013-04-04</th>
#       <td>1559.979316</td>
#     </tr>
#     <tr>
#       <th>2013-04-05</th>
#       <td>1553.278930</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df_test.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>market value</th>
#     </tr>
#     <tr>
#       <th>date</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2013-04-08</th>
#       <td>1563.071269</td>
#     </tr>
#     <tr>
#       <th>2013-04-09</th>
#       <td>1568.607909</td>
#     </tr>
#     <tr>
#       <th>2013-04-10</th>
#       <td>1587.731827</td>
#     </tr>
#     <tr>
#       <th>2013-04-11</th>
#       <td>1593.369863</td>
#     </tr>
#     <tr>
#       <th>2013-04-12</th>
#       <td>1588.854623</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# ### White Noise

# %% [markdown]
# ####White noise es utilizado para saber si a serie temporal tiene un padrao aleatorio, caso tenga un padrao aleatorio entonces no es posible hacer pronosticos con ella.

# %%
wn=np.random.normal(loc=df['market value'].mean(), scale=df['market value'].std(), size=len(df))

# %%
df['wn']=wn
# Out:
# C:\Users\User\Virtual_Alejandro\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df.describe()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>market value</th>
#       <th>wn</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>count</th>
#       <td>5021.000000</td>
#       <td>5021.000000</td>
#     </tr>
#     <tr>
#       <th>mean</th>
#       <td>1091.651926</td>
#       <td>1096.979135</td>
#     </tr>
#     <tr>
#       <th>std</th>
#       <td>292.559287</td>
#       <td>293.950555</td>
#     </tr>
#     <tr>
#       <th>min</th>
#       <td>438.920000</td>
#       <td>98.546701</td>
#     </tr>
#     <tr>
#       <th>25%</th>
#       <td>914.620000</td>
#       <td>894.161561</td>
#     </tr>
#     <tr>
#       <th>50%</th>
# ...

# %%
plt.figure(figsize=(20,5))
plt.plot(df['wn'])
plt.title('White Noise Time Series', size=24)
plt.savefig('F:/WhiteNoise.jpg')
plt.show()

# %% [markdown]
# ###Random Walk

# %%
#### Random Walk es utilizado para

# %%
rw=pd.read_csv('F:/Time series com Python/Time Series Analysis in Python 2020/05 Working with Time Series in Python/RandWalk.csv')

# %%
rw['date']=pd.to_datetime(rw['date'], dayfirst=True)
rw.set_index('date', inplace=True)
rw.asfreq(freq='b')
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>price</th>
#     </tr>
#     <tr>
#       <th>date</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1994-01-07</th>
#       <td>1122.139662</td>
#     </tr>
#     <tr>
#       <th>1994-01-10</th>
#       <td>1080.347860</td>
#     </tr>
#     <tr>
#       <th>1994-01-11</th>
#       <td>1082.095245</td>
#     </tr>
#     <tr>
#       <th>1994-01-12</th>
#       <td>1083.639265</td>
#     </tr>
#     <tr>
#       <th>1994-01-13</th>
#       <td>1067.146255</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>2013-04-01</th>
# ...

# %%
df['rw']=rw['price']
df.head()
# Out:
# C:\Users\User\Virtual_Alejandro\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>market value</th>
#       <th>wn</th>
#       <th>rw</th>
#     </tr>
#     <tr>
#       <th>date</th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
# ...

# %%
plt.figure(figsize=(20,5))
plt.plot(df['rw'])
plt.title('Random Walk',size=24)
plt.savefig('F:/RandomWalk.jpg')
plt.show()

# %%
plt.figure(figsize=(20,5))
plt.plot(df['market value'], label='market value')
plt.plot(df['rw'], label='random walk')
plt.legend(loc='best')
plt.title('Market value & Random Walk',size=24)
plt.savefig('F:/Market value & Random Walk.jpg')
plt.show()

# %%
df.describe()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>market value</th>
#       <th>wn</th>
#       <th>rw</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>count</th>
#       <td>5021.000000</td>
#       <td>5021.000000</td>
#       <td>5021.000000</td>
#     </tr>
#     <tr>
#       <th>mean</th>
#       <td>1091.651926</td>
#       <td>1096.979135</td>
#       <td>1269.944293</td>
#     </tr>
#     <tr>
#       <th>std</th>
#       <td>292.559287</td>
#       <td>293.950555</td>
#       <td>444.216793</td>
#     </tr>
#     <tr>
#       <th>min</th>
#       <td>438.920000</td>
#       <td>98.546701</td>
#       <td>585.483034</td>
#     </tr>
# ...
