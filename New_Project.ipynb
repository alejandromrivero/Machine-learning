# %%
import pandas as pd
import seaborn as sb
from matplotlib import pyplot as plt
import re

# %%
a=pd.read_excel('G:/bookings.xlsx')
plt.bar(a['Data'],a['Bookings'],width=30)
plt.grid(True, linestyle='--', color='green')
'''plt.legend(loc='best')'''
plt.title('Bookings vs timing')
# Out:
# Text(0.5, 1.0, 'Bookings vs timing')
