# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from datetime import datetime

# %%
xls=pd.read_excel('F:/ejercício de machine learning.xlsx')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-e4530f71f48e> in <module>
# ----> 1 xls=pd.read_excel('F:/ejercício de machine learning.xlsx')
#
# ~\Virtual_Alejandro\lib\site-packages\pandas\io\excel\_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, verbose, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols, **kwds)
#     302
#     303     if not isinstance(io, ExcelFile):
# --> 304         io = ExcelFile(io, engine=engine)
#     305     elif engine and engine != io.engine:
#     306         raise ValueError(
#
# ~\Virtual_Alejandro\lib\site-packages\pandas\io\excel\_base.py in __init__(self, io, engine)
#     822         self._io = stringify_path(io)
#     823
# ...

# %%
xls
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Data</th>
#       <th>A</th>
#       <th>B</th>
#       <th>C</th>
#       <th>D</th>
#       <th>E</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2001-01-01</td>
#       <td>0.532041</td>
#       <td>0.277785</td>
#       <td>5</td>
#       <td>-1.187957</td>
#       <td>Vitoria</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2001-01-02</td>
#       <td>0.129002</td>
#       <td>0.957972</td>
#       <td>2</td>
#       <td>-3.016482</td>
#       <td>San Juan</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2001-01-03</td>
#       <td>0.235785</td>
# ...

# %%
xls.groupby('E').sum()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>A</th>
#       <th>B</th>
#       <th>C</th>
#       <th>D</th>
#     </tr>
#     <tr>
#       <th>E</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Havana</th>
#       <td>2510.719002</td>
#       <td>2497.541328</td>
#       <td>20084</td>
#       <td>-7256.379949</td>
#     </tr>
#     <tr>
#       <th>Johanesburg</th>
#       <td>2523.954758</td>
#       <td>2507.270942</td>
#       <td>15000</td>
#       <td>-8971.226495</td>
#     </tr>
#     <tr>
#       <th>San Juan</th>
#       <td>2510.425617</td>
# ...

# %%
xls.describe()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>A</th>
#       <th>B</th>
#       <th>C</th>
#       <th>D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>count</th>
#       <td>20000.000000</td>
#       <td>20000.000000</td>
#       <td>20000.00000</td>
#       <td>20000.000000</td>
#     </tr>
#     <tr>
#       <th>mean</th>
#       <td>0.500591</td>
#       <td>0.501021</td>
#       <td>3.49295</td>
#       <td>-1.843132</td>
#     </tr>
#     <tr>
#       <th>std</th>
#       <td>0.288812</td>
#       <td>0.289720</td>
#       <td>1.11710</td>
#       <td>1.510675</td>
#     </tr>
#     <tr>
#       <th>min</th>
#       <td>0.000041</td>
# ...

# %%
xls['Data'].describe()
# Out:
# count                   20000
# unique                  20000
# top       2021-10-17 00:00:00
# freq                        1
# first     2001-01-01 00:00:00
# last      2055-10-04 00:00:00
# Name: Data, dtype: object

# %%
dt=pd.to_datetime(xls['Data'])
dt
# Out:
# 0       2001-01-01
# 1       2001-01-02
# 2       2001-01-03
# 3       2001-01-04
# 4       2001-01-05
# 5       2001-01-06
# 6       2001-01-07
# 7       2001-01-08
# 8       2001-01-09
# 9       2001-01-10
# 10      2001-01-11
# 11      2001-01-12
# 12      2001-01-13
# 13      2001-01-14
# 14      2001-01-15
# 15      2001-01-16
# 16      2001-01-17
# 17      2001-01-18
# 18      2001-01-19
# 19      2001-01-20
# 20      2001-01-21
# 21      2001-01-22
# 22      2001-01-23
# 23      2001-01-24
# 24      2001-01-25
# 25      2001-01-26
# 26      2001-01-27
# 27      2001-01-28
# 28      2001-01-29
# 29      2001-01-30
#            ...
# 19970   2055-09-05
# 19971   2055-09-06
# 19972   2055-09-07
# 19973   2055-09-08
# 19974   2055-09-09
# 19975   2055-09-10
# 19976   2055-09-11
# 19977   2055-09-12
# 19978   2055-09-13
# 19979   2055-09-14
# 19980   2055-09-15
# 19981   2055-09-16
# 19982   2055-09-17
# 19983   2055-09-18
# 19984   2055-09-19
# 19985   2055-09-20
# ...
