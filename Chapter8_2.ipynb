# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from statsmodels.stats.tests.test_multi import NA

# %%
arr=np.arange(12).reshape((3,4))
np.concatenate([arr,arr], axis=1)
# Out:
# array([[ 0,  1,  2,  3,  0,  1,  2,  3],
#        [ 4,  5,  6,  7,  4,  5,  6,  7],
#        [ 8,  9, 10, 11,  8,  9, 10, 11]])

# %%
indices=[[np.arange(3)],['a','b','c']]
indices
# Out:
# [[array([0, 1, 2])], ['a', 'b', 'c']]

# %%
arr1=pd.DataFrame(arr, index= [[0, 1, 2],['a','b','c']],
                  columns=['one','two','three','four'])
arr1.columns.names=['type']
arr1.index.names=['code','letra']
arr1
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>type</th>
#       <th>one</th>
#       <th>two</th>
#       <th>three</th>
#       <th>four</th>
#     </tr>
#     <tr>
#       <th>code</th>
#       <th>letra</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <th>a</th>
#       <td>0</td>
#       <td>1</td>
#       <td>2</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <th>b</th>
#       <td>4</td>
#       <td>5</td>
#       <td>6</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <th>c</th>
#       <td>8</td>
# ...

# %%
f=pd.concat([arr1,arr1])

# %%
fr=f.swaplevel('letra','code')

# %%
fr
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>type</th>
#       <th>one</th>
#       <th>two</th>
#       <th>three</th>
#       <th>four</th>
#     </tr>
#     <tr>
#       <th>letra</th>
#       <th>code</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>a</th>
#       <th>0</th>
#       <td>0</td>
#       <td>1</td>
#       <td>2</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>b</th>
#       <th>1</th>
#       <td>4</td>
#       <td>5</td>
#       <td>6</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th>c</th>
#       <th>2</th>
#       <td>8</td>
# ...

# %%
fr.sort_index(level='code')
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>type</th>
#       <th>one</th>
#       <th>two</th>
#       <th>three</th>
#       <th>four</th>
#     </tr>
#     <tr>
#       <th>letra</th>
#       <th>code</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th rowspan="2" valign="top">a</th>
#       <th>0</th>
#       <td>0</td>
#       <td>1</td>
#       <td>2</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>1</td>
#       <td>2</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th rowspan="2" valign="top">b</th>
# ...

# %%
fr.swaplevel('code','letra')
fr1=fr[fr['one']>1]
fr1['one'].sum()
# Out:
# 24

# %%
conc=np.concatenate([arr,arr], axis=0)

# %%
df=pd.DataFrame(conc,index=[np.arange(len(conc)),['a','b','c','d','e','f']],
             columns=['one','two','three','four'])
df.index.names=['Number','Type']
df
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>one</th>
#       <th>two</th>
#       <th>three</th>
#       <th>four</th>
#     </tr>
#     <tr>
#       <th>Number</th>
#       <th>Type</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <th>a</th>
#       <td>0</td>
#       <td>1</td>
#       <td>2</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <th>b</th>
#       <td>4</td>
#       <td>5</td>
#       <td>6</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <th>c</th>
#       <td>8</td>
# ...

# %%
df2=pd.DataFrame(np.random.randn(len(df)), 
                 index=[np.arange(len(conc)),['a','b','c','d','e','f']],columns=['five'])
df2.index.names=['Number','Type']

# %%
df
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>one</th>
#       <th>two</th>
#       <th>three</th>
#       <th>four</th>
#     </tr>
#     <tr>
#       <th>Number</th>
#       <th>Type</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <th>a</th>
#       <td>0</td>
#       <td>1</td>
#       <td>2</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <th>b</th>
#       <td>4</td>
#       <td>5</td>
#       <td>6</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <th>c</th>
#       <td>8</td>
# ...

# %%
df2
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>five</th>
#     </tr>
#     <tr>
#       <th>Number</th>
#       <th>Type</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <th>a</th>
#       <td>0.437214</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <th>b</th>
#       <td>0.044512</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <th>c</th>
#       <td>1.009972</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <th>d</th>
#       <td>-0.725360</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <th>e</th>
#       <td>-1.506763</td>
#     </tr>
#     <tr>
#       <th>5</th>
# ...

# %%
frame1=pd.concat([df,round(df2,4)], axis=1)
frame1
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>one</th>
#       <th>two</th>
#       <th>three</th>
#       <th>four</th>
#       <th>five</th>
#     </tr>
#     <tr>
#       <th>Number</th>
#       <th>Type</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <th>a</th>
#       <td>0</td>
#       <td>1</td>
#       <td>2</td>
#       <td>3</td>
#       <td>1.3082</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <th>b</th>
#       <td>4</td>
#       <td>5</td>
#       <td>6</td>
#       <td>7</td>
# ...

# %%
frame1.rename(columns=str.capitalize)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>One</th>
#       <th>Two</th>
#       <th>Three</th>
#       <th>Four</th>
#       <th>Five</th>
#     </tr>
#     <tr>
#       <th>Number</th>
#       <th>Type</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <th>a</th>
#       <td>0</td>
#       <td>1</td>
#       <td>2</td>
#       <td>3</td>
#       <td>1.3082</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <th>b</th>
#       <td>4</td>
#       <td>5</td>
#       <td>6</td>
#       <td>7</td>
# ...

# %%
frame1.iloc[0:2,2:3]=5

# %%
frame1
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>one</th>
#       <th>two</th>
#       <th>three</th>
#       <th>four</th>
#       <th>five</th>
#     </tr>
#     <tr>
#       <th>Number</th>
#       <th>Type</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <th>a</th>
#       <td>0</td>
#       <td>1</td>
#       <td>5</td>
#       <td>3</td>
#       <td>1.3082</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <th>b</th>
#       <td>4</td>
#       <td>5</td>
#       <td>5</td>
#       <td>7</td>
# ...

# %%
frame1.iloc[0:2,3:]
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>four</th>
#       <th>five</th>
#     </tr>
#     <tr>
#       <th>Number</th>
#       <th>Type</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <th>a</th>
#       <td>3</td>
#       <td>1.3082</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <th>b</th>
#       <td>7</td>
#       <td>0.0442</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
frame1.iloc[0:2,3:].mean()
# Out:
# four    5.0000
# five    0.6762
# dtype: float64

# %%
x=pd.Series(frame1['four'])
y=pd.Series(frame1['five'])

# %%
x
# Out:
# Number  Type
# 0       a        3
# 1       b        7
# 2       c       11
# 3       d        3
# 4       e        7
# 5       f       11
# Name: four, dtype: int32

# %%
y
# Out:
# Number  Type
# 0       a       1.3082
# 1       b       0.0442
# 2       c      -0.8015
# 3       d       0.1399
# 4       e      -1.2612
# 5       f      -0.3790
# Name: five, dtype: float64

# %%
plt.scatter(x,y, color='red',marker='o')
#plt.bar(x,y, color='blue')
plt.title('x vs y')
plt.xlabel('eixo x')
plt.ylabel('eixo y')
plt.grid(True,linestyle='--',color='blue')
plt.savefig('F:/dumps/figura_de_jupyter.jpg')

# %%
with open('F:/dumps/SELECT____valor_bruto_ISS_valor_total_NF.json','rb') as entrada:
    ler = pd.read_json(entrada)

# %%
dados=pd.DataFrame(ler)
dados.set_index(['NFSe'])
dados.columns
# Out:
# Index(['ICMS', 'ISS', 'NFSe', 'emissao', 'nota', 'pag', 'serie', 'valor_bruto',
#        'valor_nota', 'valor_total_NFSe'],
#       dtype='object')

# %%
dados.index
# Out:
# RangeIndex(start=0, stop=1098, step=1)

# %%
d=dados[['emissao','nota','NFSe']]
d
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>emissao</th>
#       <th>nota</th>
#       <th>NFSe</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2017-10-25</td>
#       <td>1</td>
#       <td>285</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2017-10-25</td>
#       <td>2</td>
#       <td>286</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2017-10-25</td>
#       <td>5</td>
#       <td>297</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>2017-10-25</td>
#       <td>6</td>
#       <td>268</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>2017-10-25</td>
#       <td>7</td>
# ...

# %%
dados[dados['emissao']<'2017-12-01'].sum()
# Out:
# ICMS                                                                0
# ISS                                                           1608.31
# NFSe                                                           170203
# emissao             2017-10-252017-10-252017-10-252017-10-252017-1...
# nota                                                           170579
# pag                                                              3676
# serie               5555555555555555555555555555555555555555555555...
# valor_bruto                                                   77318.5
# valor_nota                                                    77318.5
# valor_total_NFSe                                              78926.8
# dtype: object

# %%
d
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>emissao</th>
#       <th>nota</th>
#       <th>NFSe</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2017-10-25</td>
#       <td>1</td>
#       <td>285</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2017-10-25</td>
#       <td>2</td>
#       <td>286</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2017-10-25</td>
#       <td>5</td>
#       <td>297</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>2017-10-25</td>
#       <td>6</td>
#       <td>268</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>2017-10-25</td>
#       <td>7</td>
# ...

# %%
d.head()#   obj.head() se usa para mostrar los primeros 5 elementos do dataframe
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>emissao</th>
#       <th>nota</th>
#       <th>NFSe</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2017-10-25</td>
#       <td>1</td>
#       <td>285</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2017-10-25</td>
#       <td>2</td>
#       <td>286</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2017-10-25</td>
#       <td>5</td>
#       <td>297</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>2017-10-25</td>
#       <td>6</td>
#       <td>268</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>2017-10-25</td>
#       <td>7</td>
# ...

# %%
data=pd.read_csv('F:\DATA SCIENCE BOOKS\pydata-book-2nd-edition\examples\macrodata.csv')

# %%
data.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>year</th>
#       <th>quarter</th>
#       <th>realgdp</th>
#       <th>realcons</th>
#       <th>realinv</th>
#       <th>realgovt</th>
#       <th>realdpi</th>
#       <th>cpi</th>
#       <th>m1</th>
#       <th>tbilrate</th>
#       <th>unemp</th>
#       <th>pop</th>
#       <th>infl</th>
#       <th>realint</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1959.0</td>
#       <td>1.0</td>
#       <td>2710.349</td>
#       <td>1707.4</td>
#       <td>286.898</td>
#       <td>470.045</td>
#       <td>1886.9</td>
#       <td>28.98</td>
#       <td>139.7</td>
# ...

# %%
periods=pd.PeriodIndex(year=data.year, quarter=data.quarter, name='date')

# %%
columns=pd.Index(['realgdp','infl','unemp'], name='item')

# %%
data=data.reindex(columns=columns)

# %%
data.index=periods.to_timestamp('D','end')

# %%
ldata=data.stack().reset_index().rename(columns={0:'value'})

# %%
ldata[:10]
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>date</th>
#       <th>item</th>
#       <th>value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1959-03-31 23:59:59.999999999</td>
#       <td>realgdp</td>
#       <td>2710.349</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1959-03-31 23:59:59.999999999</td>
#       <td>infl</td>
#       <td>0.000</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>1959-03-31 23:59:59.999999999</td>
#       <td>unemp</td>
#       <td>5.800</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>1959-06-30 23:59:59.999999999</td>
#       <td>realgdp</td>
# ...

# %%
ldata['value2']=np.random.randn(len(ldata))

# %%
ldata[:10]
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>date</th>
#       <th>item</th>
#       <th>value</th>
#       <th>value2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1959-03-31 23:59:59.999999999</td>
#       <td>realgdp</td>
#       <td>2710.349</td>
#       <td>-0.651244</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1959-03-31 23:59:59.999999999</td>
#       <td>infl</td>
#       <td>0.000</td>
#       <td>-0.495835</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>1959-03-31 23:59:59.999999999</td>
#       <td>unemp</td>
#       <td>5.800</td>
#       <td>-0.008978</td>
#     </tr>
#     <tr>
# ...

# %%
pivoted=ldata.pivot('date','item')

# %%
pivoted[:10]
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead tr th {
#         text-align: left;
#     }
#
#     .dataframe thead tr:last-of-type th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr>
#       <th></th>
#       <th colspan="3" halign="left">value</th>
#       <th colspan="3" halign="left">value2</th>
#     </tr>
#     <tr>
#       <th>item</th>
#       <th>infl</th>
#       <th>realgdp</th>
#       <th>unemp</th>
#       <th>infl</th>
#       <th>realgdp</th>
#       <th>unemp</th>
#     </tr>
#     <tr>
#       <th>date</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1959-03-31 23:59:59.999999999</th>
#       <td>0.00</td>
# ...

# %%
de=pd.DataFrame({'A':[1,2,3],'B':[4,5,6],'C':[7,8,9],'key':['foo','bar','baz']})
de
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>A</th>
#       <th>B</th>
#       <th>C</th>
#       <th>key</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>4</td>
#       <td>7</td>
#       <td>foo</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>5</td>
#       <td>8</td>
#       <td>bar</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>6</td>
#       <td>9</td>
#       <td>baz</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
de.stack().unstack()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>A</th>
#       <th>B</th>
#       <th>C</th>
#       <th>key</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>4</td>
#       <td>7</td>
#       <td>foo</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>5</td>
#       <td>8</td>
#       <td>bar</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>6</td>
#       <td>9</td>
#       <td>baz</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
pd.melt(de,['key'])
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>key</th>
#       <th>variable</th>
#       <th>value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>foo</td>
#       <td>A</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>bar</td>
#       <td>A</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>baz</td>
#       <td>A</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>foo</td>
#       <td>B</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>bar</td>
#       <td>B</td>
#       <td>5</td>
#     </tr>
#     <tr>
# ...

# %%
pd.melt(de,['key']).pivot('key','variable','value').reset_index()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>variable</th>
#       <th>key</th>
#       <th>A</th>
#       <th>B</th>
#       <th>C</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>bar</td>
#       <td>2</td>
#       <td>5</td>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>baz</td>
#       <td>3</td>
#       <td>6</td>
#       <td>9</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>foo</td>
#       <td>1</td>
#       <td>4</td>
#       <td>7</td>
#     </tr>
#   </tbody>
# </table>
# </div>
