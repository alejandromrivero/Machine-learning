# %%
import pandas as pd
import numpy as np
import random
from matplotlib import pyplot as plt
from statsmodels.stats.tests.test_multi import NA
from numpy.random import randn
import seaborn as sns

# %%
lectura=pd.read_csv('G:/dumps/Libro1.csv', sep=';', index_col=['meas'])

# %%
resultado=pd.DataFrame(lectura)

# %%
resultado
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>a</th>
#       <th>b</th>
#       <th>c</th>
#       <th>d</th>
#       <th>result</th>
#     </tr>
#     <tr>
#       <th>meas</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>0.592933</td>
#       <td>5</td>
#       <td>-0.226994</td>
#       <td>4.773006</td>
#       <td>-0.998163</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>0.955808</td>
#       <td>4</td>
#       <td>-0.019629</td>
#       <td>3.980371</td>
#       <td>-0.743827</td>
#     </tr>
#     <tr>
# ...

# %%
res=resultado.replace({3:'Alejandro',4:'Fabiana',5:'Marlene',2:'Otra_gente'})
res
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>a</th>
#       <th>b</th>
#       <th>c</th>
#       <th>d</th>
#       <th>result</th>
#     </tr>
#     <tr>
#       <th>meas</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>0.592933</td>
#       <td>Marlene</td>
#       <td>-0.226994</td>
#       <td>4.773006</td>
#       <td>-0.998163</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>0.955808</td>
#       <td>Fabiana</td>
#       <td>-0.019629</td>
#       <td>3.980371</td>
#       <td>-0.743827</td>
#     </tr>
#     <tr>
# ...

# %%
r=res['b']

# %%
r.str.lower()
# Out:
# meas
# 1          marlene
# 2          fabiana
# 3        alejandro
# 4        alejandro
# 5        alejandro
#            ...
# 2996       fabiana
# 2997    otra_gente
# 2998       fabiana
# 2999       marlene
# 3000       marlene
# Name: b, Length: 3000, dtype: object

# %%
def minuscula(data):

    g=[]
    for row in data:
        value=data.str.upper()
        g.append(value)
        return g

# %%
re=pd.DataFrame(minuscula(r))
re.index
# Out:
# Index(['b'], dtype='object')

# %%
len(re.columns)
# Out:
# 3000

# %%
pd.DataFrame(re.T)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>b</th>
#     </tr>
#     <tr>
#       <th>meas</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>MARLENE</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>FABIANA</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>ALEJANDRO</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>ALEJANDRO</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>ALEJANDRO</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>2996</th>
#       <td>FABIANA</td>
#     </tr>
#     <tr>
#       <th>2997</th>
# ...
