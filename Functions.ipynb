# %%
import pandas as pd
import numpy as np
import seaborn as sb
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
data=pd.DataFrame(np.random.randn(1000, 2), index=np.arange(1000), 
                  columns=['A','B'])

# %%
data['B']=data['B']*np.arange(1000)

# %%
D=data[(data['A']>1) & (data['B']>0)]

# %%
data.plot(x='A', y='B', kind='scatter', color='red',
          marker='.', label='concentration', alpha=0.5)
plt.grid(True, linewidth=0.9)
plt.legend(loc=1, fontsize=11)
plt.xlabel('Concentration of component A', fontsize=14)
plt.ylabel('Concentration of component B', fontsize=14)
plt.title('Scatterplot of components A & B', fontsize=22)
plt.savefig('F:/scatterplot.png')

# %%
D
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>A</th>
#       <th>B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>32</th>
#       <td>1.176926</td>
#       <td>28.987321</td>
#     </tr>
#     <tr>
#       <th>38</th>
#       <td>1.360217</td>
#       <td>31.507853</td>
#     </tr>
#     <tr>
#       <th>47</th>
#       <td>1.018370</td>
#       <td>43.731256</td>
#     </tr>
#     <tr>
#       <th>72</th>
#       <td>2.001270</td>
#       <td>70.312244</td>
#     </tr>
#     <tr>
#       <th>95</th>
#       <td>1.024754</td>
#       <td>31.864110</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
# ...

# %%
def inventando(a,b):
    for i in data:
        if (a.all()>1.5):
            n=a+b
        elif a.all()<1.5:
            n=(a+b)/100
        else:
            n=a-b
        return n

# %%
e=inventando(D['A'],D['B'])

# %%
e
# Out:
# 32      0.301642
# 38      0.328681
# 47      0.447496
# 72      0.723135
# 95      0.328889
#          ...
# 938     6.981290
# 944    10.591641
# 945     1.453971
# 946     4.203776
# 962     1.338865
# Length: 70, dtype: float64

# %%
e
# Out:
# 32      0.301642
# 38      0.328681
# 47      0.447496
# 72      0.723135
# 95      0.328889
#          ...
# 938     6.981290
# 944    10.591641
# 945     1.453971
# 946     4.203776
# 962     1.338865
# Length: 70, dtype: float64

# %%
g=pd.read_excel('F:/HIST_PAINEL_COVIDBR_2020_Parte2_11set2021.xlsx')

# %%
G=pd.DataFrame(g,index=np.arange(len(g)))

# %%
G
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>regiao</th>
#       <th>estado</th>
#       <th>municipio</th>
#       <th>coduf</th>
#       <th>codmun</th>
#       <th>codRegiaoSaude</th>
#       <th>nomeRegiaoSaude</th>
#       <th>data</th>
#       <th>semanaEpi</th>
#       <th>populacaoTCU2019</th>
#       <th>casosAcumulado</th>
#       <th>casosNovos</th>
#       <th>obitosAcumulado</th>
#       <th>obitosNovos</th>
#       <th>Recuperadosnovos</th>
#       <th>emAcompanhamentoNovos</th>
#       <th>interior/metropolitana</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Brasil</td>
#       <td>NaN</td>
# ...

# %%
G_drop=G.dropna(axis=1)

# %%
print(G_drop.describe())
# Out:
#                coduf      semanaEpi  casosAcumulado     casosNovos  \
# count  859707.000000  859707.000000    8.597070e+05  859707.000000
# mean       32.360384      42.287582    2.760763e+03      17.494872
# std         9.873302       6.315948    7.388518e+04     503.801257
# min        11.000000      31.000000    0.000000e+00   -7926.000000
# 25%        25.000000      37.000000    5.600000e+01       0.000000
# 50%        31.000000      42.000000    1.710000e+02       0.000000
# 75%        41.000000      48.000000    5.390000e+02       2.000000
# max        76.000000      53.000000    7.675973e+06   70574.000000
#
#        obitosAcumulado    obitosNovos
# count    859707.000000  859707.000000
# mean         79.471762       0.357589
# std        2131.560155      10.484296
# min           0.000000    -292.000000
# 25%           1.000000       0.000000
# 50%           3.000000       0.000000
# 75%          11.000000       0.000000
# max      194949.000000    1421.000000

# %%
print(G['estado'])
# Out:
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#          ...
# 859702     DF
# 859703     DF
# 859704     DF
# 859705     DF
# 859706     DF
# Name: estado, Length: 859707, dtype: object

# %%
G_drop.columns
# Out:
# Index(['regiao', 'coduf', 'data', 'semanaEpi', 'casosAcumulado', 'casosNovos',
#        'obitosAcumulado', 'obitosNovos'],
#       dtype='object')

# %%
G_drop_grouped=G_drop.groupby(G['regiao']).mean()

# %%
G_drop_grouped.columns
# Out:
# Index(['coduf', 'semanaEpi', 'casosAcumulado', 'casosNovos', 'obitosAcumulado',
#        'obitosNovos'],
#       dtype='object')
