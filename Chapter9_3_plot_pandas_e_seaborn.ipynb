# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from statsmodels.stats.tests.test_multi import NA
from numpy.random import randn
import seaborn as sns
# %matplotlib inline

# %%
s=pd.Series(np.random.randn(10).cumsum(),index=np.arange(0,100,10))
s.plot(xlim=[-10,120], kind='bar',rot=30, ylim=[-10,10],grid=True)

# %%
df=pd.DataFrame(np.random.randn(10,4).cumsum(0),index=np.arange(0,100,10),columns=['A','B','C','D'])
df
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>A</th>
#       <th>B</th>
#       <th>C</th>
#       <th>D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0.643094</td>
#       <td>0.249534</td>
#       <td>-0.091576</td>
#       <td>1.655265</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>0.578291</td>
#       <td>-0.026034</td>
#       <td>0.125678</td>
#       <td>3.655101</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>2.782765</td>
#       <td>-0.317883</td>
#       <td>0.138960</td>
#       <td>4.326502</td>
#     </tr>
#     <tr>
#       <th>30</th>
#       <td>2.817249</td>
# ...

# %%
df.plot(title='algo para hacer',figsize=(6,6))

# %%
fig,axes=plt.subplots(2,1)
data=pd.Series(np.random.rand(16), index=list('abcdefghijklmnop'))
data.plot.bar(ax=axes[1],color='blue',alpha=0.3, grid=True)
data.plot.barh(ax=axes[0],color='red',alpha=0.8, grid=False)

# %%
df1=pd.DataFrame(np.random.rand(6,4), index=['one','two','three','four','five','six'],
                columns=['A','B','C','D'])
df1
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>A</th>
#       <th>B</th>
#       <th>C</th>
#       <th>D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>one</th>
#       <td>0.430734</td>
#       <td>0.089828</td>
#       <td>0.213687</td>
#       <td>0.051162</td>
#     </tr>
#     <tr>
#       <th>two</th>
#       <td>0.376256</td>
#       <td>0.181008</td>
#       <td>0.413757</td>
#       <td>0.112659</td>
#     </tr>
#     <tr>
#       <th>three</th>
#       <td>0.354023</td>
#       <td>0.171521</td>
#       <td>0.340051</td>
#       <td>0.118184</td>
#     </tr>
#     <tr>
#       <th>four</th>
#       <td>0.144959</td>
# ...

# %%
df1.plot.bar(ylim=[0,1.2],grid=True,alpha=1.0)
plt.title('aprendiendo a guradar archivo en png')
plt.xlabel('eje x')
plt.ylabel('eje y')
plt.savefig('F:/dumps/algo para guardar.png')

# %%
df1.plot.barh(xlim=[0,1.2],grid=True,alpha=1.0, )

# %%
tips=pd.read_csv('F:/DATA SCIENCE BOOKS/pydata-book-2nd-edition/examples/tips.csv')

# %%
tips
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>total_bill</th>
#       <th>tip</th>
#       <th>smoker</th>
#       <th>day</th>
#       <th>time</th>
#       <th>size</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>16.99</td>
#       <td>1.01</td>
#       <td>No</td>
#       <td>Sun</td>
#       <td>Dinner</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>10.34</td>
#       <td>1.66</td>
#       <td>No</td>
#       <td>Sun</td>
#       <td>Dinner</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>21.01</td>
#       <td>3.50</td>
#       <td>No</td>
# ...

# %%
party_counts=pd.crosstab(tips['day'],tips['size'])

# %%
party_counts
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>size</th>
#       <th>1</th>
#       <th>2</th>
#       <th>3</th>
#       <th>4</th>
#       <th>5</th>
#       <th>6</th>
#     </tr>
#     <tr>
#       <th>day</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Fri</th>
#       <td>1</td>
#       <td>16</td>
#       <td>1</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Sat</th>
#       <td>2</td>
#       <td>53</td>
#       <td>18</td>
#       <td>13</td>
#       <td>1</td>
#       <td>0</td>
#     </tr>
# ...

# %%
party_counts=party_counts.loc[:,2:5]

# %%
party_counts
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>size</th>
#       <th>2</th>
#       <th>3</th>
#       <th>4</th>
#       <th>5</th>
#     </tr>
#     <tr>
#       <th>day</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Fri</th>
#       <td>16</td>
#       <td>1</td>
#       <td>1</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Sat</th>
#       <td>53</td>
#       <td>18</td>
#       <td>13</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>Sun</th>
#       <td>39</td>
#       <td>15</td>
#       <td>18</td>
#       <td>3</td>
#     </tr>
#     <tr>
# ...

# %%
party_pcts=party_counts.div(party_counts.sum(1), axis=0)

# %%
party_pcts
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>size</th>
#       <th>2</th>
#       <th>3</th>
#       <th>4</th>
#       <th>5</th>
#     </tr>
#     <tr>
#       <th>day</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Fri</th>
#       <td>0.888889</td>
#       <td>0.055556</td>
#       <td>0.055556</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <th>Sat</th>
#       <td>0.623529</td>
#       <td>0.211765</td>
#       <td>0.152941</td>
#       <td>0.011765</td>
#     </tr>
#     <tr>
#       <th>Sun</th>
#       <td>0.520000</td>
#       <td>0.200000</td>
# ...

# %%
party_pcts.plot.bar()

# %%
tips['tip_pct']=tips['tip']/(tips['total_bill']-tips['tip'])
tips.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>total_bill</th>
#       <th>tip</th>
#       <th>smoker</th>
#       <th>day</th>
#       <th>time</th>
#       <th>size</th>
#       <th>tip_pct</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>16.99</td>
#       <td>1.01</td>
#       <td>No</td>
#       <td>Sun</td>
#       <td>Dinner</td>
#       <td>2</td>
#       <td>0.063204</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>10.34</td>
#       <td>1.66</td>
#       <td>No</td>
#       <td>Sun</td>
#       <td>Dinner</td>
#       <td>3</td>
#       <td>0.191244</td>
#     </tr>
#     <tr>
#       <th>2</th>
# ...

# %%
sns.barplot(x='tip_pct', y='day',data=tips,orient='h', alpha=0.8)

# %%
sns.barplot(x='tip_pct',y='day',hue='time',data=tips,orient='h')
sns.set(style='whitegrid')

# %%
tips['tip_pct'].plot.density()

# %%
comp1=np.random.normal(0,1,size=200)
comp2=np.random.normal(10,2,size=200)
values=pd.Series(np.concatenate([comp1, comp2]))
sns.distplot(values,bins=100,color='blue')

# %%
macro=pd.read_csv('F:\DATA SCIENCE BOOKS\pydata-book-2nd-edition\examples\macrodata.csv')

# %%
macro
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>year</th>
#       <th>quarter</th>
#       <th>realgdp</th>
#       <th>realcons</th>
#       <th>realinv</th>
#       <th>realgovt</th>
#       <th>realdpi</th>
#       <th>cpi</th>
#       <th>m1</th>
#       <th>tbilrate</th>
#       <th>unemp</th>
#       <th>pop</th>
#       <th>infl</th>
#       <th>realint</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1959.0</td>
#       <td>1.0</td>
#       <td>2710.349</td>
#       <td>1707.4</td>
#       <td>286.898</td>
#       <td>470.045</td>
#       <td>1886.9</td>
#       <td>28.980</td>
#       <td>139.7</td>
# ...

# %%
data2=macro[['cpi','m1','tbilrate','unemp']]

# %%
data2
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>cpi</th>
#       <th>m1</th>
#       <th>tbilrate</th>
#       <th>unemp</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>28.980</td>
#       <td>139.7</td>
#       <td>2.82</td>
#       <td>5.8</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>29.150</td>
#       <td>141.7</td>
#       <td>3.08</td>
#       <td>5.1</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>29.350</td>
#       <td>140.5</td>
#       <td>3.82</td>
#       <td>5.3</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>29.370</td>
#       <td>140.0</td>
#       <td>4.33</td>
# ...

# %%
trans_data2=np.log(data2).diff().dropna()

# %%
trans_data2[-5:]
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>cpi</th>
#       <th>m1</th>
#       <th>tbilrate</th>
#       <th>unemp</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>198</th>
#       <td>-0.007904</td>
#       <td>0.045361</td>
#       <td>-0.396881</td>
#       <td>0.105361</td>
#     </tr>
#     <tr>
#       <th>199</th>
#       <td>-0.021979</td>
#       <td>0.066753</td>
#       <td>-2.277267</td>
#       <td>0.139762</td>
#     </tr>
#     <tr>
#       <th>200</th>
#       <td>0.002340</td>
#       <td>0.010286</td>
#       <td>0.606136</td>
#       <td>0.160343</td>
#     </tr>
#     <tr>
#       <th>201</th>
# ...

# %%
sns.regplot('m1','unemp',data=trans_data2, color='k',marker='s')
plt.plot(figsize=(10,10))
fig.suptitle('Changes in log m1 versus log unemp')
plt.savefig('F:\dumps\Saida de regplot do seaborn.jpg')

# %%
sns.heatmap(data=trans_data2,vmin=-2.0)

# %%
sns.pairplot(trans_data2,diag_kind='hist',plot_kws={'alpha':0.2})
plt.suptitle('Pairplot Graph', y=1, fontsize=16)

plt.savefig('F:/dumps/saida de paiplot.png')

# %%
sns.catplot(x='day',y='tip_pct',hue='time',col='smoker',kind='bar',data=tips[tips.tip_pct<1])

# %%
sns.catplot(x='day',y='tip_pct',row='time',col='smoker',kind='bar',data=tips[tips.tip_pct<1])
