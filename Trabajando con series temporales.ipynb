# %%
import pandas as pd
import numpy as np
import datetime
import matplotlib.pyplot as plt
import seaborn as sb

# %%
valor=pd.DataFrame(np.random.randint(2,50,size=5000),columns=['Valor'], index=np.arange(5000))
valor.index.names=['indice']
valor
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Valor</th>
#     </tr>
#     <tr>
#       <th>indice</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>48</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>16</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>49</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>43</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>35</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>21</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>34</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>47</td>
#     </tr>
#     <tr>
# ...

# %%
valor1=pd.DataFrame(np.random.rand(5000)+np.random.randint(2,8), columns=['Valor1'], index=np.arange(5000))
valor1.index.names=['indice']
valor1
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Valor1</th>
#     </tr>
#     <tr>
#       <th>indice</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>5.207059</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>5.570122</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>5.218562</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>5.950530</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>5.309617</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>5.397176</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>5.950140</td>
#     </tr>
#     <tr>
#       <th>7</th>
# ...

# %%
data=pd.DataFrame(pd.date_range(start='2020-01-01',periods=5000, freq='D'),columns=['Data'],index=np.arange(5000))
data.index.names=['indice']
data
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Data</th>
#     </tr>
#     <tr>
#       <th>indice</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2020-01-01</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2020-01-02</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2020-01-03</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>2020-01-04</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>2020-01-05</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>2020-01-06</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>2020-01-07</td>
#     </tr>
#     <tr>
# ...

# %%
valor2=pd.DataFrame(np.random.randint(2,150,size=5000),columns=['Valor2'], index=np.arange(5000))
valor2.index.names=['indice']
valor2
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Valor2</th>
#     </tr>
#     <tr>
#       <th>indice</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>16</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>80</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>32</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>95</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>104</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>41</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>84</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>129</td>
#     </tr>
# ...

# %%
df1=pd.merge(data, valor, on='indice')
df1
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Data</th>
#       <th>Valor</th>
#     </tr>
#     <tr>
#       <th>indice</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2020-01-01</td>
#       <td>48</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2020-01-02</td>
#       <td>16</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2020-01-03</td>
#       <td>49</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>2020-01-04</td>
#       <td>43</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>2020-01-05</td>
#       <td>35</td>
#     </tr>
#     <tr>
# ...

# %%
df2=pd.DataFrame(pd.merge(df1,valor1, on='indice'))
df3=pd.DataFrame(pd.merge(df2,valor2, on='indice'))
df3
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Data</th>
#       <th>Valor</th>
#       <th>Valor1</th>
#       <th>Valor2</th>
#     </tr>
#     <tr>
#       <th>indice</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2020-01-01</td>
#       <td>48</td>
#       <td>5.207059</td>
#       <td>16</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2020-01-02</td>
#       <td>16</td>
#       <td>5.570122</td>
#       <td>80</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2020-01-03</td>
#       <td>49</td>
#       <td>5.218562</td>
# ...

# %%
df3.set_index('Data')
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Valor</th>
#       <th>Valor1</th>
#       <th>Valor2</th>
#     </tr>
#     <tr>
#       <th>Data</th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2020-01-01</th>
#       <td>48</td>
#       <td>5.207059</td>
#       <td>16</td>
#     </tr>
#     <tr>
#       <th>2020-01-02</th>
#       <td>16</td>
#       <td>5.570122</td>
#       <td>80</td>
#     </tr>
#     <tr>
#       <th>2020-01-03</th>
#       <td>49</td>
#       <td>5.218562</td>
#       <td>32</td>
#     </tr>
#     <tr>
#       <th>2020-01-04</th>
#       <td>43</td>
# ...

# %%
df3.dtypes
# Out:
# Data      datetime64[ns]
# Valor              int32
# Valor1           float64
# Valor2             int32
# dtype: object

# %%
df3['Data']=pd.DatetimeIndex(df2['Data'])

# %%
df3.dtypes
# Out:
# Data      datetime64[ns]
# Valor              int32
# Valor1           float64
# Valor2             int32
# dtype: object

# %%
df3=df3.set_index('Data')

# %%
df4=pd.DataFrame(df3.resample('Y').mean())
df4.corr()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Valor</th>
#       <th>Valor1</th>
#       <th>Valor2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Valor</th>
#       <td>1.000000</td>
#       <td>0.284841</td>
#       <td>-0.018607</td>
#     </tr>
#     <tr>
#       <th>Valor1</th>
#       <td>0.284841</td>
#       <td>1.000000</td>
#       <td>-0.081669</td>
#     </tr>
#     <tr>
#       <th>Valor2</th>
#       <td>-0.018607</td>
#       <td>-0.081669</td>
#       <td>1.000000</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df4
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Valor</th>
#       <th>Valor1</th>
#       <th>Valor2</th>
#     </tr>
#     <tr>
#       <th>Data</th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2020-12-31</th>
#       <td>25.005464</td>
#       <td>5.470154</td>
#       <td>79.407104</td>
#     </tr>
#     <tr>
#       <th>2021-12-31</th>
#       <td>25.619178</td>
#       <td>5.504014</td>
#       <td>75.613699</td>
#     </tr>
#     <tr>
#       <th>2022-12-31</th>
#       <td>25.210959</td>
#       <td>5.491840</td>
#       <td>76.057534</td>
#     </tr>
#     <tr>
# ...

# %%
plt.plot(df4.index,df4['Valor'], color='grey', linewidth=1.9)
plt.xticks(df4.index, rotation=60, color='blue')
plt.yticks(df4['Valor'], color='blue', rotation=0, fontsize=10)
plt.xlabel('Ano', color='red',fontsize=18)
plt.ylabel('Valores arrecadados (milhões)', fontsize=18, color='blue')
plt.grid(True, linestyle='--', color='blue', linewidth=0.5)

# %%
sb.scatterplot(df4.index,df4['Valor'], label='Valor arrecadado no periodo', color='red', markers='*')
plt.xlim('2019-12-31','2034-12-31')
plt.xlabel('Ano', color='red',fontsize=18)
plt.ylabel('Valores arrecadados (milhões)', fontsize=18, color='blue')
plt.xticks(df4.index, rotation=90, color='blue')
#plt.yticks(df4['Valor'], color='blue', rotation=0, fontsize=10)
plt.grid(True, linestyle='--', color='blue', linewidth=0.5)
plt.legend(loc='best', fontsize=12)

# %%
df4.count()
# Out:
# Valor     14
# Valor1    14
# Valor2    14
# dtype: int64

# %%
plt.hist(df4['Valor1'],bins=9)
# Out:
# (array([1., 1., 0., 0., 3., 6., 2., 0., 1.]),
#  array([5.46209882, 5.46925784, 5.47641686, 5.48357587, 5.49073489,
#         5.49789391, 5.50505293, 5.51221195, 5.51937097, 5.52652998]),
#  <a list of 9 Patch objects>)

# %%
categoria=pd.cut(df4['Valor'], bins=6)
categoria
# Out:
# Data
# 2020-12-31     (24.988, 25.35]
# 2021-12-31     (25.35, 25.713]
# 2022-12-31     (24.988, 25.35]
# 2023-12-31     (25.35, 25.713]
# 2024-12-31     (25.35, 25.713]
# 2025-12-31      (26.438, 26.8]
# 2026-12-31    (26.075, 26.438]
# 2027-12-31    (25.713, 26.075]
# 2028-12-31    (26.075, 26.438]
# 2029-12-31    (25.713, 26.075]
# 2030-12-31    (24.623, 24.988]
# 2031-12-31     (24.988, 25.35]
# 2032-12-31     (25.35, 25.713]
# 2033-12-31    (24.623, 24.988]
# Freq: A-DEC, Name: Valor, dtype: category
# Categories (6, interval[float64]): [(24.623, 24.988] < (24.988, 25.35] < (25.35, 25.713] < (25.713, 26.075] < (26.075, 26.438] < (26.438, 26.8]]

# %%
contagem=pd.value_counts(categoria)
contagem
# Out:
# (25.35, 25.713]     4
# (24.988, 25.35]     3
# (26.075, 26.438]    2
# (25.713, 26.075]    2
# (24.623, 24.988]    2
# (26.438, 26.8]      1
# Name: Valor, dtype: int64

# %%
df5=pd.DataFrame(df3.resample('W').sum())
df5['Valor_new']=((df5['Valor2']-df5['Valor'])**(df5['Valor1']*0.05)/10000000)
df5
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Valor</th>
#       <th>Valor1</th>
#       <th>Valor2</th>
#       <th>Valor_new</th>
#     </tr>
#     <tr>
#       <th>Data</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2020-01-05</th>
#       <td>191</td>
#       <td>27.255890</td>
#       <td>327</td>
#       <td>0.000081</td>
#     </tr>
#     <tr>
#       <th>2020-01-12</th>
#       <td>268</td>
#       <td>38.169969</td>
#       <td>455</td>
#       <td>0.002167</td>
#     </tr>
#     <tr>
#       <th>2020-01-19</th>
#       <td>139</td>
#       <td>39.166976</td>
# ...

# %%
df5.corr()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Valor</th>
#       <th>Valor1</th>
#       <th>Valor2</th>
#       <th>Valor_new</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Valor</th>
#       <td>1.000000</td>
#       <td>-0.014477</td>
#       <td>-0.026596</td>
#       <td>-0.300953</td>
#     </tr>
#     <tr>
#       <th>Valor1</th>
#       <td>-0.014477</td>
#       <td>1.000000</td>
#       <td>0.058553</td>
#       <td>0.301287</td>
#     </tr>
#     <tr>
#       <th>Valor2</th>
#       <td>-0.026596</td>
#       <td>0.058553</td>
#       <td>1.000000</td>
#       <td>0.840639</td>
#     </tr>
#     <tr>
#       <th>Valor_new</th>
# ...

# %%
plt.figure(figsize=(16, 8))
sb.set(style="whitegrid")
plt.scatter(df5['Valor1'],df5['Valor_new'], marker='o',alpha=0.5, color='black', label='Valor_new')
plt.scatter(df5['Valor1'],df5['Valor2'], marker='H',alpha=0.7,color='blue' ,label='Valor2')
plt.legend(loc='best')
plt.title('Valores que foram arrecadados entre 2020-2033 embora não foram tomadas as medidas indicadas', 
          color='grey', fontsize=22,pad=10)
plt.suptitle('Datas limites vs Valores arrecadados', color='black', fontsize=28)
plt.grid(True, linewidth=0.8, linestyle='--')
plt.xlabel('Valor1', color='black', fontsize=28)
plt.ylabel('Vaalor_new',color='black',fontsize=28)
plt.savefig('F:/testando o grafffico.jpg', bbox_inches='tight')
