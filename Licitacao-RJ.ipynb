# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sn

# %%
lote1=pd.read_excel('G:/licita/Libro1.xlsx')
lote1.columns
# Out:
# Index(['ITEM', 'SETOR', 'EQUIPAMENTO', 'MARCA', 'MODELO', 'SÉRIE', 'Locação',
#        'Patrimônio', 'Lote '],
#       dtype='object')

# %%
resumolote1=pd.DataFrame(lote1.groupby(['EQUIPAMENTO','MARCA','MODELO'])
                         ['EQUIPAMENTO'].count())

# %%
resumolote1.to_excel('G:/licita/RESUMO1.xlsx')

# %%
lote1['SETOR']=lote1['SETOR'].str.upper()
lote1['EQUIPAMENTO']=lote1['EQUIPAMENTO'].str.upper()
lote1['MARCA']=lote1['MARCA'].str.upper()
lote1['MODELO']=lote1['MODELO'].str.upper()
lote1['SÉRIE']=lote1['SÉRIE'].str.upper()
lote1['TOTAL']=0

# %%
resumolote1=pd.DataFrame(lote1.groupby(['EQUIPAMENTO','MARCA','MODELO'])
                         ['TOTAL'].count())
resumolote1.to_excel('G:/licita/RESUMO1.xlsx')

# %%
lote2=pd.read_excel('G:/licita/Libro2.xlsx')
lote2.columns
# Out:
# Index(['ITEM', 'SETOR', 'EQUIPAMENTO', 'MARCA', 'MODELO', 'SÉRIE', 'Locação'], dtype='object')

# %%
lote2['SETOR']=lote2['SETOR'].str.upper()
lote2['EQUIPAMENTO']=lote2['EQUIPAMENTO'].str.upper()
lote2['MARCA']=lote2['MARCA'].str.upper()
lote2['MODELO']=lote2['MODELO'].str.upper()
lote2['SÉRIE']=lote2['SÉRIE'].str.upper()
lote2['TOTAL']=0

# %%
lote2
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>ITEM</th>
#       <th>SETOR</th>
#       <th>EQUIPAMENTO</th>
#       <th>MARCA</th>
#       <th>MODELO</th>
#       <th>SÉRIE</th>
#       <th>Locação</th>
#       <th>TOTAL</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>ALA A</td>
#       <td>CAMA HOSPITALAR ELÉTRICA</td>
#       <td>STRYKER</td>
#       <td>FL-23</td>
#       <td>J16288</td>
#       <td>HEER</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>ALA A</td>
#       <td>CAMA HOSPITALAR ELÉTRICA</td>
#       <td>STRYKER</td>
#       <td>FL-23</td>
# ...

# %%
resumolote2=pd.DataFrame(lote2.groupby(['EQUIPAMENTO','MARCA','MODELO'])
                         ['TOTAL'].count())
resumolote2.to_excel('G:/licita/RESUMO2.xlsx')
